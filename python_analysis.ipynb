# %%
import pandas as pd

# %%
df =  pd.read_csv("Diwali Sales Data.csv", encoding='unicode_escape')
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
df["Status"].unique()
# Out:
# array([nan])

# %%
df['unnamed1'].unique()
# Out:
# array([nan])

# %%
# all values of status column are null and unnamed1 column has also null so remove them
df.drop(columns=["Status","unnamed1"], inplace=True)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# checking duplicates in data
df[df.duplicated() == True]
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 19     1001883     Praneet  P00029842      M     51-55   54               1
# 4404   1004725     Jackson  P00150842      F     36-45   37               1
# 5703   1003208      Bowman  P00171642      F     26-35   31               0
# 5908   1001260     Dheeraj  P00344042      M     26-35   28               0
# 6173   1001325       Reese  P00111742      F     26-35   27               1
# 8651   1000083        Gute  P00242842      M     26-35   35               0
# 8941   1001476     Anudeep  P00036842      M     18-25   25               0
# 10571  1004404  Rittenbach  P00150142      F     26-35   28               1
#
#                State      Zone    Occupation       Product_Category  Orders  \
# 19     Uttar Pradesh   Central   Hospitality                   Auto       1
# 4404     Maharashtra   Western   Hospitality  Electronics & Gadgets       4
# ...

# %%
duplicate = df[df.duplicated(keep='last')]
duplicate
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 18     1001883     Praneet  P00029842      M     51-55   54               1
# 4403   1004725     Jackson  P00150842      F     36-45   37               1
# 5702   1003208      Bowman  P00171642      F     26-35   31               0
# 5907   1001260     Dheeraj  P00344042      M     26-35   28               0
# 6172   1001325       Reese  P00111742      F     26-35   27               1
# 8650   1000083        Gute  P00242842      M     26-35   35               0
# 8940   1001476     Anudeep  P00036842      M     18-25   25               0
# 10570  1004404  Rittenbach  P00150142      F     26-35   28               1
#
#                State      Zone    Occupation       Product_Category  Orders  \
# 18     Uttar Pradesh   Central   Hospitality                   Auto       1
# 4403     Maharashtra   Western   Hospitality  Electronics & Gadgets       4
# ...

# %%
#dropping duplicated data
data = df.drop_duplicates()

# %%
data.duplicated().unique()
# Out:
# array([False])

# %%
# finding sales ratio between men and women
data['Gender'].value_counts(normalize=True) * 100
# Out:
# F    69.714489
# M    30.285511
# Name: Gender, dtype: float64

# %% [markdown]
# ### Observation: almost 70% productss are ordered by Women only and 30% productss are ordered by Men

# %%
# finding sales ratio between different age-groups
data['Age Group'].value_counts(normalize=True) * 100
# Out:
# 26-35    40.362892
# 36-45    20.323757
# 18-25    16.703727
# 46-50     8.778796
# 51-55     7.391266
# 55+       3.806813
# 0-17      2.632749
# Name: Age Group, dtype: float64

# %% [markdown]
# ### Observation: 40% - most products are ordered by age group 26-35 only..
# ### only 2.63% - least products are ordered by age group below 17yrs

# %%
# finding sales ratio between married and unmarried people
data['Marital_Status'].value_counts(normalize=True) * 100
# Out:
# 0    57.97385
# 1    42.02615
# Name: Marital_Status, dtype: float64

# %% [markdown]
# ### Obeservation: Unmarried people are ordering more frequently in comparison to married people

# %%
# Finding sales ratio between different states across india
data['State'].value_counts(normalize=True) * 100
# Out:
# Uttar Pradesh       17.290759
# Maharashtra         13.546207
# Karnataka           11.607222
# Delhi                9.846126
# Madhya Pradesh       8.209553
# Andhra Pradesh       7.222272
# Himachal Pradesh     5.407809
# Kerala               4.029174
# Haryana              4.011385
# Bihar                3.851285
# Gujarat              3.806813
# Jharkhand            3.379881
# Uttarakhand          2.846215
# Rajasthan            2.054612
# Punjab               1.778885
# Telangana            1.111803
# Name: State, dtype: float64

# %% [markdown]
# ### Observation: Uttar Pradesh is the state with the highest number of orders in this dataset followed by Maharastra and Karnataka

# %%
data['Zone'].value_counts(normalize=True) * 100
# Out:
# Central     38.192653
# Southern    23.970471
# Western     17.353020
# Northern    13.252691
# Eastern      7.231166
# Name: Zone, dtype: float64

# %% [markdown]
# ### Central Zone has the highest number of orders in this dataset

# %%
data['Occupation'].value_counts(normalize=True) * 100
# Out:
# IT Sector          14.106555
# Healthcare         12.523348
# Aviation           11.642800
# Banking            10.130748
# Govt                7.595837
# Hospitality         6.243885
# Media               5.665748
# Automobile          5.034244
# Chemical            4.820777
# Lawyer              4.722939
# Retail              4.456106
# Food Processing     3.762341
# Construction        3.673397
# Textile             3.113048
# Agriculture         2.508227
# Name: Occupation, dtype: float64

# %% [markdown]
# ### People working in IT sector are ordering more follwed by Healthcare and aviation industry..

# %%
data['Product_Category'].value_counts(normalize=True) * 100
# Out:
# Clothing & Apparel       23.596905
# Food                     22.173797
# Electronics & Gadgets    18.518189
# Footwear & Shoes          9.463666
# Household items           4.625100
# Beauty                    3.753447
# Games & Toys              3.433247
# Sports Products           3.166415
# Furniture                 3.139731
# Pet Care                  1.885618
# Office                    1.005070
# Stationery                0.996175
# Books                     0.916126
# Auto                      0.880548
# Decor                     0.853865
# Veterinary                0.720448
# Tupperware                0.640398
# Hand & Power Tools        0.231255
# Name: Product_Category, dtype: float64

# %% [markdown]
# ### Highest orders belongs to Clothing & Apparel product category and 2nd most caegory is Food..

# %%
data[data["Amount"] == data['Amount'].max()]
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
#
#          State     Zone  Occupation Product_Category  Orders   Amount
# 0  Maharashtra  Western  Healthcare             Auto       1  23952.0

# %% [markdown]
# ### highest order amount is 23952 from Maharashtra from healthcare sector and product category is Auto

# %%
data[data["Amount"] == data['Amount'].min()]
# Out:
#        User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11250  1002744   Brumley  P00281742      F     18-25   19               0
#
#              State     Zone  Occupation Product_Category  Orders  Amount
# 11250  Maharashtra  Western  Healthcare           Office       3   188.0

# %% [markdown]
# ### lowest order amount is 188 from Maharashtra from healthcare sector and product category is Office

# %%
data.groupby("Product_Category").max()
# Out:
#                        User_ID  Cust_name Product_ID Gender Age Group  Age  \
# Product_Category
# Auto                   1005908     Zypern   P0096942      M       55+   83
# Beauty                 1006036     Zypern   P0099242      M       55+   89
# Books                  1005916  Wasserman   P0097742      M       55+   88
# Clothing & Apparel     1006039     percer   P0099342      M       55+   92
# Decor                  1005954     Yoseph   P0097242      M       55+   81
# Electronics & Gadgets  1006039     percer   P0099442      M       55+   91
# Food                   1006037     percer   P0099742      M       55+   92
# Footwear & Shoes       1006040     percer   P0099242      M       55+   92
# Furniture              1005982     percer   P0099242      M       55+   92
# Games & Toys           1006040        Zic   P0099042      M       55+   91
# Hand & Power Tools     1005780    Vasudev  P00358442      M       55+   85
# ...

# %% [markdown]
# ### Though most of the orders(40%) are coming from age group 26-35 but maximum order value per categories are ordered by 55+ age group people..
# ### Though most of the orders(70%) are given by Women but All Highest order amount in each categories are belongs to Men only
# ### Most of the order are given by people having IT sector and Healthcare sector, Costliest products are purchased by people having occupations with Textile
# ### Most of the costliest products are ordered from Uttarakhand people. western zone are speding more amount

# %%
data.groupby("Occupation").max()
# Out:
#                  User_ID Cust_name Product_ID Gender Age Group  Age  \
# Occupation
# Agriculture      1006016    Zypern   P0099042      M       55+   91
# Automobile       1006036     liebe   P0099442      M       55+   90
# Aviation         1006040    percer   P0098442      M       55+   92
# Banking          1006036    percer   P0099342      M       55+   92
# Chemical         1006036    Zypern   P0099342      M       55+   92
# Construction     1006021    percer   P0099342      M       55+   92
# Food Processing  1006040    Zypern   P0099242      M       55+   87
# Govt             1006036     Zydlo   P0099742      M       55+   91
# Healthcare       1006036     liebe   P0099342      M       55+   92
# Hospitality      1006039    percer   P0098242      M       55+   90
# IT Sector        1006040     liebe   P0099442      M       55+   92
# Lawyer           1006039    percer   P0098742      M       55+   89
# Media            1006040     liebe   P0097242      M       55+   92
# ...

# %%
for cat in categories:
    print(cat)
    d = data[ data['Product_Category'] == cat and data["Amount"] == data['Amount'].max()]
    d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_456\1576092985.py in <module>
# ----> 1 for cat in categories:
#       2     print(cat)
#       3     d = data[ data['Product_Category'] == cat and data["Amount"] == data['Amount'].max()]
#       4     d
#
# NameError: name 'categories' is not defined
